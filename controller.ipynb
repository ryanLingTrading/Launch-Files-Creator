# %%
# %run ./fn_def_n_examples.ipynb

# %%
import ipynb.fs.full.fn_def_n_examples as fn ## make sure it is in same directory
# Out:
# volume.gate.spot.SAITO.USDT.saito.gate-spot-0 apiVersion: microservice.flowdesk.co/v1alpha1
# kind: Volume
# metadata:
#   labels:
#     app.kubernetes.io/managed-by: flux
#     app.kubernetes.io/created-by: flux
#   name: volume.gate.spot.SAITO.USDT.saito.gate-spot-0
#   namespace: saito
# spec:
#   deploymentSpec:
#     projectId: infrastructure-prod-92821
#     imageName: asia-northeast1-docker.pkg.dev/infrastructure-prod-92821/main-asia/flowdeskmarkets/volume
#     imageTag: v3.4.0
#   settings:
#     accountID: gate-spot-0
#     authType: private
#     clientName: saito
#     currency1: SAITO
#     currency2: USDT
#     dynamicSettings:
#       V0: 3800
#       baseProbabilityThreshold: 0.0015
#       digitsPrice: 5
#       digitsVolume: 2
#       directionalityFactor: 0.65
#       minStepVolume: 0
#       minTradeAmount: 200
#       preventSpreadCrossing: true
#       priceNoiseRange: 0.005
#       priceStep: 100
#       priceVolatilityFactor: 1
#       pushToExecutor: false
# ...

# %%
dir(fn) ## defined functions and objs
# Out:
# ['INDEX_TEMPLATE_PATH',
#  'PRIVATE_TEMPLATE_FPATH',
#  'PUBLIC_TEMPLATE_PATH',
#  'TEMPLATE_BASE_PATH',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'config_file',
#  'fname_prefix',
#  'fname_to_redis_key',
#  'generate_aggregation_yaml_from_file',
#  'index_delta',
#  'index_position_factor',
#  'parameters',
#  'private_balance_agg',
#  'private_orderbook_agg',
#  'private_trades_agg',
#  'public_orderbook_agg',
#  'public_tick_agg',
#  'public_trades_agg',
#  'write_yaml_to_file',
#  'yaml',
#  'yaml_text']

# %%
help(fn.public_orderbook_agg)
# Out:
# Help on function public_orderbook_agg in module ipynb.fs.full.fn_def_n_examples:
#
# public_orderbook_agg(exchange, exchangeType, exchangeProtocol, currency1, currency2, config_fpath='/Users/ryan.ling/Documents/0. Python/trading_tools/Launch Files Creator/configs_templates/public_base_config.yaml')
#     Generates a public order book aggregation YAML file based on the provided exchange, exchange type, exchange protocol, and currency pairs.
#
#     This function constructs a dictionary of parameters, including exchange details and currency pairs, and uses these to generate a YAML file.
#     It then loads the YAML file, optionally modifies it by adding or removing fields, and finally returns the filename prefix and the modified YAML text.
#
#     Parameters:
#         exchange (str): The name of the exchange.
#         exchangeType (str): The type of the exchange (e.g., centralized, decentralized).
# ...
